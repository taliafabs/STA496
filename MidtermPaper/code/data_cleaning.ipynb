# %% [markdown]
# <a href="https://colab.research.google.com/github/taliafabs/STA496/blob/main/MidtermPaper/code/data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Workplace setup
import pandas as pd
import numpy as np

# %%
# Download the data via url from Harvard dataverse
# !wget --no-check-certificate "https://dataverse.harvard.edu/api/access/datafile/11043166" -O CES24_Common.dta
# Out:
# --2025-07-19 16:05:45--  https://dataverse.harvard.edu/api/access/datafile/11043166
# Resolving dataverse.harvard.edu (dataverse.harvard.edu)... 18.213.92.174, 98.85.1.147, 3.230.40.224
# Connecting to dataverse.harvard.edu (dataverse.harvard.edu)|18.213.92.174|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://dvn-cloud.s3.amazonaws.com/10.7910/DVN/X11EP6/195f789b49c-5243179a19d3?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27CES24_Common.dta&response-content-type=application%2Fx-stata-13&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20250719T160545Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=AKIAIEJ3NV7UYCSRJC7A%2F20250719%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=0a182de374e4db01a1f8e71cbf24bf2471ae41ceb9230b69ecaeddba6132af64 [following]
# --2025-07-19 16:05:45--  https://dvn-cloud.s3.amazonaws.com/10.7910/DVN/X11EP6/195f789b49c-5243179a19d3?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27CES24_Common.dta&response-content-type=application%2Fx-stata-13&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20250719T160545Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=AKIAIEJ3NV7UYCSRJC7A%2F20250719%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=0a182de374e4db01a1f8e71cbf24bf2471ae41ceb9230b69ecaeddba6132af64
# Resolving dvn-cloud.s3.amazonaws.com (dvn-cloud.s3.amazonaws.com)... 54.231.172.9, 3.5.29.135, 16.15.193.152, ...
# Connecting to dvn-cloud.s3.amazonaws.com (dvn-cloud.s3.amazonaws.com)|54.231.172.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 822758249 (785M) [application/x-stata-13]
# Saving to: ‘CES24_Common.dta’
#
# CES24_Common.dta    100%[===================>] 784.64M  28.9MB/s    in 29s
#
# 2025-07-19 16:06:14 (27.4 MB/s) - ‘CES24_Common.dta’ saved [822758249/822758249]

# %%
ces24 = pd.read_stata("CES24_Common.dta")
ces24.head()
# Out:
#        caseid tookpost  commonweight  commonpostweight CCEStake add_confirm  \
# 0  1853651564      Yes      0.418897          0.180057      Yes         Yes
# 1  1853655732      Yes      0.946650          0.700897      Yes         NaN
# 2  1852716424      Yes      0.194303          0.046275      Yes         Yes
# 3  1853644254      Yes      0.083223          0.008897      Yes         NaN
# 4  1853644132      Yes      0.596598          0.555395      Yes         Yes
#
#   inputzip  birthyr gender4 gender4_t  ... page_CC24_445_timing  \
# 0      NaN     1978   Woman    __NA__  ...               13.454
# 1  11236.0     1968     Man    __NA__  ...                4.454
# 2      NaN     1946   Woman    __NA__  ...               21.204
# 3  90039.0     2001   Woman    __NA__  ...               64.011
# 4      NaN     1955   Woman    __NA__  ...              164.473
#
#   page_gunown_timing page_numchildren_timing page_gigwork_timing  \
# 0              0.000                   4.736               5.564
# 1              0.000                  15.087               9.487
# 2              0.000                  16.130               9.494
# 3              0.000                   4.617              55.219
# 4              8.722                   6.011              37.659
#
#   page_edloan_timing page_student_timing     starttime       endtime  \
# 0              0.000               0.000  2.043432e+12  2.043433e+12
# 1              0.000               0.000  2.043433e+12  2.043434e+12
# 2              0.000               0.000  2.043432e+12  2.043434e+12
# 3              0.000               2.347  2.043432e+12  2.043434e+12
# 4              5.242               0.000  2.043432e+12  2.043435e+12
#
#   starttime_post  endtime_post
# 0   2.046740e+12  2.046741e+12
# 1   2.046898e+12  2.046899e+12
# 2   2.046916e+12  2.046917e+12
# 3   2.049248e+12  2.049251e+12
# 4   2.046556e+12  2.046558e+12
#
# [5 rows x 684 columns]

# %%
ces24.columns
# Out:
# Index(['caseid', 'tookpost', 'commonweight', 'commonpostweight', 'CCEStake',
#        'add_confirm', 'inputzip', 'birthyr', 'gender4', 'gender4_t',
#        ...
#        'page_CC24_445_timing', 'page_gunown_timing', 'page_numchildren_timing',
#        'page_gigwork_timing', 'page_edloan_timing', 'page_student_timing',
#        'starttime', 'endtime', 'starttime_post', 'endtime_post'],
#       dtype='object', length=684)

# %%
# CES survey 2024 data cleaning
ces24_subset = ces24[['CC24_364a', # 2024 pres vote
                      'CC24_364b', # preferred presidential candidate
                      'race', # what race best describes you
                      'birthyr', # year respondent was born
                      'hispanic', # hispanic?
                      'gender4', # gender identity
                      'educ', # highest level of education completed
                      'inputstate', # state of residence
                      'region', # region of residence
                      'urbancity', # type of area respondent lives in
                      'CC24_301', # national economy over the past year
                      'CC24_302', # family income past year
                      'CC24_303', # price change past year
                      'CC24_312a', # biden approval
                      'tookpost' # whether the respondent took the post election wave
                      ]]

ces24_subset['age'] = 2024 - ces24_subset['birthyr']

# create age bracket variable
ces24_subset['age_bracket'] = pd.cut(
    ces24_subset['age'],
    bins=[17, 24, 34, 44, 54, 64, 74, 100],
    labels=[
        '18–24', '25–34', '35–44', '45–54', '55–64', '65–74', '75+'
    ]
)

# only include trump, harris, and third party voters
ces24_subset = ces24_subset[
    (ces24_subset['CC24_364a'] == "Kamala Harris (Democrat)") |
    (ces24_subset['CC24_364a'] == "Donald Trump (Republican)") |
    (ces24_subset['CC24_364b'] == "Kamala Harris (Democrat)") |
    (ces24_subset['CC24_364b'] == "Donald Trump (Republican)") |
    (ces24_subset['CC24_364a'] == "Someone else") |
    (ces24_subset['CC24_364b'] == "Other")
]

ces24_subset['vote_trump'] = np.where(
    (ces24_subset['CC24_364a'] == "Donald Trump (Republican)") |
    (ces24_subset['CC24_364b'] == "Donald Trump (Republican)"),
    1, 0
)

conditions = [
    (((ces24_subset['CC24_364a'] == "Donald Trump (Republican)") |
     (ces24_subset['CC24_364b'] == "Donald Trump (Republican)")) &
      (ces24_subset['CC24_364a'] != "Kamala Harris (Democrat)") &
       (ces24_subset['CC24_364b'] != "Kamala Harris (Democrat)")
       ), # Trump
    ((ces24_subset['CC24_364a'] == "Kamala Harris (Democrat)") | (ces24_subset['CC24_364b'] == "Kamala Harris (Democrat)")) # Harris
]
choices = ['Donald Trump (R)', 'Kamala Harris (D)']
ces24_subset['presvote24'] = np.select(conditions, choices, default='Other')

# ces24_subset['vote_harris'] = 1 - ces24_subset['vote_trump']
# ces24_subset['presvote24'] = np.where(ces24_subset['vote_trump'] == 1, 'Donald Trump (R)', 'Kamala Harris (D)')

# subset again
ces24_df = ces24_subset[['vote_trump',
                            #  'vote_harris',
                             'presvote24',
                             'race',
                             'age_bracket',
                             'birthyr',
                             'hispanic',
                             'gender4',
                             'educ',
                             'inputstate',
                             'region',
                             'urbancity',
                             'CC24_301',
                             'CC24_302',
                             'CC24_303',
                             'CC24_312a',
                             'tookpost'
                             ]]

# drop na
ces24_analysis_df = ces24_df[ces24_df['tookpost'] == "Yes"]
ces24_analysis_df = ces24_analysis_df.dropna()
# Out:
# /tmp/ipython-input-53-4269901690.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ces24_subset['age'] = 2024 - ces24_subset['birthyr']
# /tmp/ipython-input-53-4269901690.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ces24_subset['age_bracket'] = pd.cut(

# %%
ces24_analysis_df.presvote24.value_counts()
# Out:
# presvote24
# Kamala Harris (D)    24932
# Donald Trump (R)     19446
# Other                 1554
# Name: count, dtype: int64

# %%
# do some re-naming
ces24_analysis_df = ces24_analysis_df.rename(columns={'CC24_301': 'econ_past_year',
                                                      'CC24_302': 'family_income_past_year',
                                                      'CC24_303': 'price_change_past_year',
                                                      'CC24_312a': 'biden_approval',
                                                      'inputstate': 'state'
                                                      })

# %%
ces24_analysis_df.head()
# Out:
#    vote_trump         presvote24      race age_bracket  birthyr hispanic  \
# 0           0  Kamala Harris (D)     Black       45–54     1978       No
# 1           0  Kamala Harris (D)  Hispanic       55–64     1968      Yes
# 2           0  Kamala Harris (D)     White         75+     1946       No
# 3           0  Kamala Harris (D)     White       18–24     2001      Yes
# 4           0              Other     White       65–74     1955       No
#
#   gender4                  educ         state     region urbancity  \
# 0   Woman  High school graduate  Pennsylvania  Northeast      City
# 1     Man                4-year      New York  Northeast      City
# 2   Woman                2-year  Pennsylvania  Northeast    Suburb
# 3   Woman  High school graduate    California       West    Suburb
# 4   Woman  High school graduate       Montana       West      Town
#
#           econ_past_year family_income_past_year price_change_past_year  \
# 0  Stayed about the same   Stayed about the same  Stayed about the same
# 1     Gotten much better   Stayed about the same     Increased somewhat
# 2     Gotten much better   Stayed about the same     Decreased somewhat
# 3      Gotten much worse   Stayed about the same        Increased a lot
# 4      Gotten much worse   Stayed about the same        Increased a lot
#
#         biden_approval tookpost
# 0     Strongly approve      Yes
# 1     Strongly approve      Yes
# 2     Strongly approve      Yes
# 3  Strongly disapprove      Yes
# 4  Somewhat disapprove      Yes

# %%
# breakdown of trump and harris voters
ces24_analysis_df['presvote24'].value_counts()
# Out:
# presvote24
# Kamala Harris (D)    24932
# Donald Trump (R)     19446
# Other                 1554
# Name: count, dtype: int64

# %%
# write new file and save to google drive
# make sure this gets uploaded onto github
# mount drive
from google.colab import drive
drive.mount('/content/drive')
# binary dataset for logistic modeling (only includes Trump and Harris)
output_path = "/content/drive/MyDrive/STA496/Datasets/ces24_analysis_data.parquet"
ces24_analysis_df.to_parquet(output_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Presidential election results

# %%
# Retrieve the election data
url = "https://raw.githubusercontent.com/fivethirtyeight/election-results/main/election_results_presidential.csv"
election_df = pd.read_csv(url)
election_df.head()
# Out:
#       id  race_id state_abbrev state  office_id     office_name  \
# 0  17637     6427          NaN   NaN          1  U.S. President
# 1  17560     6425          NaN   NaN          1  U.S. President
# 2  17573     6425          NaN   NaN          1  U.S. President
# 3  17591     6425          NaN   NaN          1  U.S. President
# 4  17554     6425          NaN   NaN          1  U.S. President
#
#    office_seat_name  cycle    stage  special  ... candidate_id  \
# 0               NaN   2008  primary    False  ...      18734.0
# 1               NaN   2004  primary    False  ...        167.0
# 2               NaN   2004  primary    False  ...      18616.0
# 3               NaN   2004  primary    False  ...      20784.0
# 4               NaN   2004  primary    False  ...        157.0
#
#             candidate_name  ballot_party ranked_choice_round votes  percent  \
# 0           Philip Epstein           DEM                 NaN   NaN      NaN
# 1          Al Sharpton Jr.           DEM                 NaN   NaN      NaN
# 2  Edward Thomas O'Donnell           DEM                 NaN   NaN      NaN
# 3     George Henry Ballard           DEM                 NaN   NaN      NaN
# 4               John Kerry           DEM                 NaN   NaN      NaN
#
#    unopposed  winner alt_result_text  \
# 0        NaN   False             NaN
# 1        NaN   False             NaN
# 2        NaN   False             NaN
# 3        NaN   False             NaN
# 4        NaN    True             NaN
#
#                                               source
# 0  https://www.fec.gov/introduction-campaign-fina...
# 1  https://www.fec.gov/introduction-campaign-fina...
# 2  https://www.fec.gov/introduction-campaign-fina...
# 3  https://www.fec.gov/introduction-campaign-fina...
# 4  https://www.fec.gov/introduction-campaign-fina...
#
# [5 rows x 22 columns]

# %%
election_df['candidate_name'].unique()
# Out:
# array(['Philip Epstein', 'Al Sharpton Jr.', "Edward Thomas O'Donnell",
#        'George Henry Ballard', 'John Kerry', 'Richard A. Gephardt',
#        'Dennis J. Kucinich', 'Carol Moseley-Braun', 'Lyndon LaRouche',
#        'Randolph Wilson Crow', "'Ray J' Raymond Caplette",
#        'Vincent S. Hamm', 'Caroline Pettinato Killeen', 'L.D. Talbow',
#        'Willie Felix Carter', 'Gerry Dokka', 'Dianne Barker',
#        'Robert H. Linnell', 'Keith Brand', 'Katherine Bateman',
#        'Huda Muhammad', 'R. Randy Lee', 'Mildred Williams Glover',
#        'William Barchilon', 'Evelyn Louise Vitullo', 'Florence Walker',
#        'Lucian Jacob Wojciechowski', 'Jeanne Chebib',
#        'Vermin Love Supreme', 'Jeremy Robinson-Leon',
#        'William H.T. McGaughey', 'Arthur H. Jackson', 'Fern Penna',
#        'Hillary Rodham Clinton', 'Joseph I. Lieberman', 'Wesley Clark',
#        'John Edwards', 'Howard Dean', 'Harry W. Braun', 'Michael Oatman',
#        'Libby Hubbard', 'Rich Lee', 'Peter Bollander', 'Chuck See',
#        'Karl Krueger', 'Frank Lynch', 'William Campbell',
#        'Sandy Whitehouse', 'Edward Dobson', 'Phillip Tanner',
#        'Albert Binyahmin Howard', 'William Keefe', 'Tom Laughlin',
#        'Stephen W. Marchuk', 'Orion Karl Daley', 'Eric Hinzman',
#        'Dal Anthony LaMagna', 'Jim Rogers', 'William C. Huges',
#        'Henry Hewes', 'David Robert Frey', 'Richard Edward Caligiuri',
#        'Michael P. Skok', 'Ralph Spelbring', 'Brian F. Calef',
#        'Darrel Reece Hunter', 'Joseph McAndrew', 'Kenneth A. Capalbo',
#        'Loti Gest', 'Leland Montell', 'Tish Haymer', 'Ole Savior',
#        'Barack Obama', 'Thomas G. Koos', 'Richard Arnold Grayson',
#        'Christopher J. Dodd', 'Mike Gravel', 'Bill Richardson',
#        'Joe Biden', 'Elizabeth H. Dole', 'George W. Bush',
#        'Tim Lee Mosby', 'Dorian Yeager', 'Samuel Harper Berry',
#        'Richard C. Peet', 'Mark Harnes', 'Lawrence L. Hornung',
#        'Thomas L. Oyler', 'James T. Zanon', 'John R. McGrath',
#        'Charles Bass Urban', 'James Attia', 'John McCain', 'Steve Forbes',
#        'Orrin G. Hatch', 'Joseph Charles Schriner', 'Alan Keyes',
#        'Gary L. Bauer', 'Jerry Ralph Curry', 'Giannibicego Hoa Tran',
#        'Hugh Cort', 'David Ruben', 'Karen Irish', 'Daniel Gilbert',
#        'Virgil L. R. Wiles', 'Sean Murphy', 'Michael Burzynski',
#        'H Neal Fendig', 'Jack E. Shepard', 'Mark Irwin Klein',
#        'John Michael Fitzpatrick', 'Charles Skelley', 'Bob L. Forthan',
#        'Rick Outzen', 'Michael P. Shaw', 'Vernon E. Wuensche', 'John Cox',
#        'Duncan Hunter', 'Ron Paul', 'Sam Brownback',
#        'Rudolph W. Giuliani', 'Mike Huckabee', 'Mitt Romney',
#        'Tom Tancredo', 'James Creighton Mitchell',
#        'Rhett Rosenquest Smith', "Cornelius Edward O'Connor",
#        'Fred Thompson', 'Timothy Cook', 'Brooks Andrews Cullison',
#        'Lindsey Graham', 'Paul Ryan', 'James Orlando Ogle',
#        'Peter Messina', 'Piyush Amrit Jindal', 'George Pataki',
#        'Stephen Bradley Comley', 'John Richard Kasich', 'Ted Cruz',
#        'Benjamin S. Carson', 'Rick Santorum', 'Marco Rubio',
#        'David Eames Hall', 'Richard P.H. Witz', 'Robert L. Mann',
#        'J. Daniel Dyas', 'David P. Thomson', 'Kevin Glenn Huey',
#        'John Dowell', 'Chomi Prag', 'Joe Robinson',
#        'Stephen John McCarthy', 'Darryl W. Perry', 'Andy Martin',
#        'Matt Drozd', 'Joann Breivogel', 'Jim Lynch', 'Victor Williams',
#        'Donald J. Gonzales', 'Walter N. Iwachiw', 'James Germalio',
#        'Frederic Vidal', 'Troy Hugh Southern', 'James Alexander-Pace',
#        'Elizabeth Gray', 'Donald Trump', 'James S. Gilmore III',
#        'Chris Christie', 'Jeb Bush', 'Rand Paul', 'Carly Fiorina',
#        'Calvis L. Hawes', 'Jim Webb', 'Paul Farrell',
#        'Steven Roy Lipscomb', 'Keith Russell Judd', 'Bernie Sanders',
#        "Martin O'Malley", 'Lloyd Thoman Kelso', 'WIllie Wilson',
#        'Steve Burke', 'Elizabeth Ann Warren', 'Michael A. Steinberg',
#        'Michael Bloomberg', 'Lawrence Lessig', 'Samuel Sloan',
#        "Brian James O'Neill", 'Richard Lyons Weil', 'Brock C. Hutton',
#        'James Valentine', 'David John Thistle', 'Bill French',
#        'Raymond Michael Moroz', 'John Wolfe', 'Graham Schwass',
#        'Star Locke', 'Larry Cohen', 'Mark Stewart Greenstein',
#        'Robert Lovitt', 'Eric Elbot', 'Jon Adams', 'Edward Sonnino',
#        'Mark Sanford', 'Mary Maxwell', 'Eric Merrill',
#        'Robert Moulton-Ely', 'Lawrence Robert Horn', 'William N. Murphy',
#        'Matthew John Matern', 'Zoltan Gyurko Istvan', 'Robert Ardini',
#        'Rick Kraft', 'Denis C. Grasska', 'Juan Payne',
#        'Robert Lee Manning', 'William F. Weld', 'Joe Walsh',
#        'Roque De La Fuente', 'Lorenz Kraus', 'Pete Buttigieg',
#        'Michael Ellinger', 'Amy Klobuchar', 'Kamala Harris',
#        'Deval Patrick', 'Tulsi Gabbard', 'Andrew Yang', 'Steve Bullock',
#        'Mosie Boyd', 'Jason Evritte Dunlap', 'Velma Steinman',
#        'Rita Krichevsky', 'Leonard J. Steinman', 'Stephen Burke',
#        'Ben Gleiberman', 'Thomas James Torgesen', 'William C. Haas',
#        'Joe Sestak', 'John Delaney', 'Julián Castro', 'Tom Steyer',
#        'Robert Wells', 'Nathan Bloxham', 'Cory A. Booker',
#        'Marianne Williamson', 'Michael Bennet', 'Charles Buckley',
#        'Nathaniel Thomas Mullins', 'Jim Taylor', 'John B. Eaton',
#        'Heather Anne Harder', 'Richard Jan Epstein', 'Jeffrey B. Peters',
#        'Bill Bradley', 'Al Gore', 'Angus Wheeler McDonald',
#        'William Parker Kreml', 'Pat Price', 'Bill Wyatt',
#        'Michael A. Callis', 'Richard Allen Holtz', 'George Gostigian',
#        'Nancy Warrick', 'Robert Edward Haines', 'Bradley J. Barton',
#        'Doc Castellano', 'Richard P. Bosa', 'Mildred T. Howard',
#        'Stephen Ashby', 'John Donald Rigazio', 'John Buchanan',
#        'Matt Welch', 'Newt Gingrich', 'Gary Johnson',
#        'Jon M. Huntsman, Jr.', 'Jeremy Hannon', 'Rick Perry',
#        'Fred Karger', 'Buddy Roemer', 'Michele Bachmann',
#        'Sheldon Yeu Howard', 'Donald James Gonzales', 'Herman Cain',
#        'Linden Swift', 'Sarah Gonzales', 'Michael Stephen Levinson',
#        'Wayne Charles Arnett', 'Mark Benjamin Linn',
#        'James A. Vestermark', 'Al Perry', 'Ronald Zack', 'Rickey Story',
#        'Cesar Cisneros', 'Raymond Scott Perkins', 'Christopher V. Hill',
#        'Mark Callahan', 'Keith Drummond', 'Donald Benjamin',
#        'Timothy D. Brewer', 'Jim Terr', 'Paul Douglas Sims',
#        'Stewart J. Greenleaf', 'Kip Dean', 'Bear Betzler', 'Jeff Lawman',
#        'L. John Davis', 'Michael J. Meehan', 'Kevin Rubash',
#        'Robert Allen Greene', 'Robert B. Jordan', 'Ed Cowan',
#        'Luis Alberto Ramos', 'Michael W.R. Meyer', 'John Davis Haywood',
#        'Darcy G. Richardson', 'Craig Freis', 'Aldous C. Tyler',
#        'Claudia De La Cruz', 'Peter Sonski', 'Cornel West',
#        'Brian Kienitz', 'Cherunda L. Fox', 'Doug Jenkins',
#        'Andrew Romon McNeil', 'Future Madam Potus', nan,
#        'Randall A. Terry', 'Robert F. Kennedy', 'Chase Oliver',
#        'Jill Stein', 'Laura Ebke', 'Shiva Ayyadurai',
#        'William P. Stodden', 'Joel Skousen', 'Jay Bowman',
#        'Rachele Fruit', 'DaWanda Shelton', 'President R. Boddie',
#        'Joseph Kishore', 'Mattie Preston', 'Richard Mayers',
#        'John P. Albers', 'Heather Lynn Stone', 'Andre Ramon McNeil',
#        'James Timothy Struck', 'Jerome Samuel White', 'Shondra Irving',
#        'David J. Nash', 'Latrina Peete', 'Kevin P. McKee',
#        'Gordan Hlavenka', 'Mike ter Maat', 'Garry Hubbard',
#        'Rudolph Ware', 'Melina Abdullah', 'Susan Maude Buchser-Lochocki',
#        'Billy Kelley', 'James D. Soderna', 'John Cheng',
#        'William Nalbach', 'Nala Baozun Scott Johnson', 'Carol Asher',
#        'Paij Boring', 'Tom Hoefling', 'Christopher Garrity',
#        'Michael Wood', 'Jesse Cuellar', 'Richard Austing Duncan',
#        'Lucifer Everylove', 'Steve M. Johnson', 'Blake Huber',
#        'Brian Anthony Perry', 'Bill Frankel', 'Doug Bell', 'Rick Mattox',
#        'Angela J. Dwyer', 'Michael F. Yost', 'Lester H. Waller',
#        'Benjamin Schwalb', 'Theo Brown', 'John R. Gibb',
#        'Jokie Beckett Jr.', 'Sethatina Newman', 'Ralph W. Jaffe',
#        'Sharon E. Harris', 'Raymond Anthony Scollin', "Andrew O'Donnell",
#        'Vivek G. Ramaswamy', 'Ryan Binkley',
#        'Armando "Mando" Perez-Serrato', 'David Stuckenberg',
#        'Nikki Haley', 'Ron DeSantis', 'Terrisa Bukovinac',
#        'Dean Phillips', 'Jason Michael Palmer', 'David Michael Olscamp',
#        'Perry Johnson', 'Stephen Lyons', 'Rachel Swift', 'Cenk Uygur',
#        'Eban Cambridge', 'Frank Joseph Lozada', 'Asa Hutchinson',
#        'John Anthony Castro', 'Gabriel Antonio Cornejo', 'Doug Burgum',
#        'Tim Scott', 'Ryan Ehrenreich', 'Wayne Anthony Pope',
#        'Richard Gutierrez', 'James Mark Merts', 'Reed Michaelsen',
#        'Cristina Nicole Grappo', 'Mark R. Prascak', 'Stephen Alan Leon',
#        'Brent Foutz', 'Superpayaseria Reese Crystalroc', 'Donald Picard',
#        'Hirsh Singh', 'Darius L. Mitchell', 'Scott Peterson Merrell',
#        'Glenn J. Mcpeters', 'Donald Mays Kjornes', 'Peter Jedick',
#        'Robert S. Carney', 'Scott Alan Ayers', 'Mike Pence', 'John Vail',
#        'Richard Rist', 'Paperboy Love Prince', 'Derek Nadeau',
#        'Paul V. LaCava', 'Alyson Kennedy', 'Gloria La Riva',
#        'Jo Jorgensen', 'William Robert Hammons', 'Mark R. Charles',
#        'Edward Shlikas', 'Charles Mitchell Williams', 'David A. Martin',
#        'Johnson Lee', 'Connie L. Gammon', 'Shawn W. Howard',
#        'Tara Renee Hunter', 'Angela Marie Walls-Windhauser',
#        'Timothy Allen Stevens', 'Jeanne Shaheen',
#        'Peter William Sherrill', 'Dennis Andrew Ball', 'Loren Collins',
#        'Deborah Rouse', 'Andy Williams', 'Condoleezza Rice',
#        'Randall Foltyniewkz', 'Jeremy Higgs', 'Barbara Ruth Bellar',
#        'Jesse Ventura', 'Valerie McCray', 'Chris Sununu',
#        'John Richard Myers', 'John Manimas', 'Daniel Clyde Cummings',
#        'Joseph W. McHugh', 'Kasey Wells',
#        'Princess Khadajah M. Jacob-Fambro', 'James Johnson',
#        'Sheila Tittle', 'Kathryn Gibson', 'Brian T. Carroll',
#        'Christopher Ryan Stried', 'Keith C. McCormic',
#        'Richard Charles Montanye', 'Christopher Lafontaine',
#        'Zachary Scalf', 'Albert Raley', 'Paul Hodges',
#        'Michael A. Laboch', 'Sharon Wallace', 'Jordan Scott',
#        'Todd Cella', 'Karynn Weinstein', 'John Farney',
#        'Mary Ruth Caro Simmons', 'David C. Byrne', 'Kyle Kenley Kopitke',
#        'Robert Morrow', 'Michelle Obama', 'Andrew Cuomo', 'Abram Loeb',
#        'Phil Collins', 'Ricki Sue King', 'Katherine Forbes',
#        'Dario David Hunter', 'Howie Hawkins', 'Jerome Michael Segal',
#        'Brooke Paige', 'Gary Swing', 'Brock Pierce', 'Don Blankenship',
#        'Kanye West', 'Jade Simmons', 'David Lee Rice', 'Evan McMullin',
#        'Dan R. Vacek', 'Darrell Castle', 'Ben Hartnell',
#        'Michael A. Maturen', 'Kevin Moreau', 'Laurence J. Kotlikoff',
#        'James Arthur Hedges', 'Mike Smith', 'Rocky Giordani',
#        'Monica Moorehead', 'Lynn Sandra Kahn', 'Emidio Mimi Soltysik',
#        'Frank Atwood', 'Christopher Robert Keniston', 'Ryan Alan Scott',
#        'Joseph Allen Maldonado', 'Bradford Lyttle', 'Rod Silva',
#        'William B. Feegbeh', 'Peter Alan Skewes', 'Arlon Scott Copeland',
#        'Anthony Valdivia', 'Scott Cubbler', 'Andrew Daniel Basiago',
#        'Doug Terry', 'Ignacio Nuñez', 'David Formhals', 'Jill Steinberg',
#        'Bill Murray', 'Tom Cruise', 'Tom Brady', 'James O. Hall',
#        'Steven M. Lafond', 'Ross C. Anderson', 'Virgil H. Goode',
#        'Roseanne Cherie Barr', 'Peta Lindsay', 'Jill Ann Reed',
#        'Jerry Litzel', 'James Harris', 'Thomas Robert Stevens',
#        'Merlin Miller', 'Stewart A. Alexander', 'Andre N. Barnett',
#        'Jim Carlson', 'Will Christensen', 'Barbara Dale Washer',
#        'Charles O. Baldwin', 'Lowell Jackson Fellure', 'Dean D. Morstad',
#        'Jeffrey Harlan Boss', 'Santa Claus', 'Avery L. Ayers',
#        'Thaddaus Hill', 'Bob Barr', 'Ralph Nader', 'Cynthia Ann McKinney',
#        'Brian Patrick Moore', 'Roger Calero', 'Gene Amondson',
#        'Gary Nettles', 'Charles Jay', 'Jonathan E. Allen',
#        'John Joseph Polachek', 'Ted C. Weill', 'Jeffrey J. Wamboldt',
#        'George David Joseph Phillies', 'Frank Edward McEnulty',
#        'Donald Kenneth Allen', 'Joel Gary Neuberg', 'Edward Marshall',
#        'William Van Auken', 'Stanford E. Andress',
#        'Michael Anthony Peroutka', 'Earl F. Dodge', 'Michael Badnarik',
#        'David Keith Cobb', 'Walter F. Brown', 'Leonard Peltier',
#        'John Kennedy', 'John T. Parker', 'Thomas J. Harens',
#        'Martin Wishnatsky', 'Andrew J. Falk', 'John Hagelin',
#        'Howard Phillips', 'Harry Browne', 'Patrick J. Buchanan',
#        'Randall Venson', 'Cathy Gordon Brown', 'Louis G. Youngkeit',
#        'David E. McReynolds', 'Dennis I. Lane'], dtype=object)

# %%
election_df.columns
# Out:
# Index(['id', 'race_id', 'state_abbrev', 'state', 'office_id', 'office_name',
#        'office_seat_name', 'cycle', 'stage', 'special', 'party',
#        'politician_id', 'candidate_id', 'candidate_name', 'ballot_party',
#        'ranked_choice_round', 'votes', 'percent', 'unopposed', 'winner',
#        'alt_result_text', 'source'],
#       dtype='object')

# %%
results_2024 = election_df[
    (election_df['cycle'] == 2024) &
    (election_df['stage'] == 'general') &
    (
        (election_df['candidate_name'] == 'Donald Trump') |
        (election_df['candidate_name'] == 'Kamala Harris')
    ) &
    (
        (election_df['ballot_party'] == 'DEM') |
        (election_df['ballot_party'] == 'REP')
    ) &
    (election_df['office_name'] == 'U.S. President')
]
results_2024
# Out:
#         id  race_id state_abbrev                 state  office_id  \
# 389  38572     8905           WI             Wisconsin          1
# 390  38571     8905           WI             Wisconsin          1
# 404  39795     8772           DC  District of Columbia          1
# 405  39794     8772           DC  District of Columbia          1
# 407  39761     8809           M1            Maine CD-1          1
# ..     ...      ...          ...                   ...        ...
# 866  39256     8814           MD              Maryland          1
# 896  39335     8851           NJ            New Jersey          1
# 897  39334     8851           NJ            New Jersey          1
# 906  39407     8860           NY              New York          1
# 909  39406     8860           NY              New York          1
#
#         office_name  office_seat_name  cycle    stage  special  ...  \
# 389  U.S. President               NaN   2024  general    False  ...
# 390  U.S. President               NaN   2024  general    False  ...
# 404  U.S. President               NaN   2024  general    False  ...
# 405  U.S. President               NaN   2024  general    False  ...
# 407  U.S. President               NaN   2024  general    False  ...
# ..              ...               ...    ...      ...      ...  ...
# 866  U.S. President               NaN   2024  general    False  ...
# 896  U.S. President               NaN   2024  general    False  ...
# 897  U.S. President               NaN   2024  general    False  ...
# 906  U.S. President               NaN   2024  general    False  ...
# 909  U.S. President               NaN   2024  general    False  ...
#
#     candidate_id  candidate_name  ballot_party ranked_choice_round      votes  \
# 389      16651.0    Donald Trump           REP                 NaN  1697626.0
# 390      16661.0   Kamala Harris           DEM                 NaN  1668229.0
# 404      16661.0   Kamala Harris           DEM                 NaN   294185.0
# 405      16651.0    Donald Trump           REP                 NaN    21076.0
# 407      16661.0   Kamala Harris           DEM                 NaN   261038.0
# ..           ...             ...           ...                 ...        ...
# 866      16661.0   Kamala Harris           DEM                 NaN  1902577.0
# 896      16651.0    Donald Trump           REP                 NaN  1968215.0
# 897      16661.0   Kamala Harris           DEM                 NaN  2220713.0
# 906      16651.0    Donald Trump           REP                 NaN  3257166.0
# 909      16661.0   Kamala Harris           DEM                 NaN  4341375.0
#
#        percent  unopposed  winner alt_result_text  \
# 389  49.595871        NaN    True             NaN
# 390  48.737042        NaN   False             NaN
# 404  90.277075        NaN    True             NaN
# 405   6.467630        NaN   False             NaN
# 407  59.798136        NaN    True             NaN
# ..         ...        ...     ...             ...
# 866  62.619087        NaN    True             NaN
# 896  46.064631        NaN   False             NaN
# 897  51.974162        NaN    True             NaN
# 906  39.421095        NaN   False             NaN
# 909  52.543148        NaN    True             NaN
#
#                                                 source
# 389  https://elections.wi.gov/sites/default/files/d...
# 390  https://elections.wi.gov/sites/default/files/d...
# 404  https://electionresults.dcboe.org/election_res...
# 405  https://electionresults.dcboe.org/election_res...
# 407  https://www.nytimes.com/interactive/2024/11/05...
# ..                                                 ...
# 866  https://elections.maryland.gov/elections/2024/...
# 896  https://www.nj.gov/state/elections/assets/pdf/...
# 897  https://www.nj.gov/state/elections/assets/pdf/...
# 906          https://elections.ny.gov/election-results
# 909          https://elections.ny.gov/election-results
#
# [114 rows x 22 columns]

# %%
results_2024['state'].nunique()
# Out:
# 57

# %%
# make the 2024 results alphabetical by state
results_2024 = results_2024.sort_values(by=['state'])

# %%
# make a data frame with necessary columns
presresults24_df = results_2024[['state',
                                 'state_abbrev',
                                 'candidate_name',
                                 'ballot_party',
                                 'votes',
                                 'percent',
                                 'winner'
                                ]]
presresults24_df
# Out:
#              state state_abbrev candidate_name ballot_party      votes  \
# 710        Alabama           AL   Donald Trump          REP  1462616.0
# 711        Alabama           AL  Kamala Harris          DEM   772412.0
# 732         Alaska           AK   Donald Trump          REP   184458.0
# 733         Alaska           AK  Kamala Harris          DEM   140026.0
# 522        Arizona           AZ   Donald Trump          REP  1770242.0
# ..             ...          ...            ...          ...        ...
# 838  West Virginia           WV  Kamala Harris          DEM   214309.0
# 390      Wisconsin           WI  Kamala Harris          DEM  1668229.0
# 389      Wisconsin           WI   Donald Trump          REP  1697626.0
# 589        Wyoming           WY   Donald Trump          REP   192633.0
# 590        Wyoming           WY  Kamala Harris          DEM    69527.0
#
#        percent winner
# 710  64.572092   True
# 711  34.100720  False
# 732  54.544809   True
# 733  41.406128  False
# 522  52.217048   True
# ..         ...    ...
# 838  28.103002  False
# 390  48.737042  False
# 389  49.595871   True
# 589  71.598005   True
# 590  25.841857  False
#
# [114 rows x 7 columns]

# %%
# make another df to structure it similarly to the CES state by state
actual_state_vote_pct = presresults24_df[['state', 'state_abbrev', 'candidate_name', 'votes', 'percent']]
# make the results for both candidates show up in the same row
actual_state_vote_pct = actual_state_vote_pct.pivot(index='state', columns='candidate_name', values='percent')
# make it a pandas df
actual_state_vote_pct = pd.DataFrame(actual_state_vote_pct)
# remove the candidate_name and just have state, trump harris
actual_state_vote_pct = actual_state_vote_pct.reset_index()
actual_state_vote_pct = actual_state_vote_pct.rename(columns={'Donald Trump': 'Donald Trump (R)', 'Kamala Harris': 'Kamala Harris (D)'})
actual_state_vote_pct = actual_state_vote_pct[['state', 'Donald Trump (R)', 'Kamala Harris (D)']]
actual_state_vote_pct = actual_state_vote_pct.sort_values(by=['state'])
actual_state_vote_pct.columns.name = None
actual_state_vote_pct_df = actual_state_vote_pct.reset_index(drop=True)
actual_state_vote_pct_df['Other'] = 100 - actual_state_vote_pct_df['Donald Trump (R)'] - actual_state_vote_pct_df['Kamala Harris (D)']
actual_state_vote_pct_df
# Out:
#                    state  Donald Trump (R)  Kamala Harris (D)     Other
# 0                Alabama         64.572092          34.100720  1.327188
# 1                 Alaska         54.544809          41.406128  4.049063
# 2                Arizona         52.217048          46.689818  1.093134
# 3               Arkansas         64.196872          33.559910  2.243218
# 4             California         38.332902          58.467704  3.199394
# 5               Colorado         43.142844          54.127686  2.729469
# 6            Connecticut         41.893906          56.398372  1.707722
# 7               Delaware         41.790989          56.492732  1.716279
# 8   District of Columbia          6.467630          90.277075  3.255296
# 9                Florida         56.088343          42.988293  0.923364
# 10               Georgia         50.717295          48.525292  0.757412
# 11                Hawaii         37.480284          60.585135  1.934581
# 12                 Idaho         66.874095          30.381867  2.744038
# 13              Illinois         43.474955          54.370574  2.154470
# 14               Indiana         58.581417          39.623118  1.795465
# 15                  Iowa         55.726820          42.517310  1.755870
# 16                Kansas         57.156308          41.040727  1.802965
# 17              Kentucky         64.472145          33.937470  1.590384
# 18             Louisiana         60.215249          38.210242  1.574509
# 19                 Maine         45.464081          52.401383  2.134536
# 20            Maine CD-1         37.967892          59.798136  2.233971
# 21            Maine CD-2         53.751744          44.223653  2.024602
# 22              Maryland         34.082823          62.619087  3.298090
# 23         Massachusetts         36.022827          61.219270  2.757904
# 24              Michigan         49.727110          48.312909  1.959982
# 25             Minnesota         46.683139          50.922549  2.394312
# 26           Mississippi         60.932637          38.028138  1.039225
# 27              Missouri         58.490642          40.082402  1.426956
# 28               Montana         58.389443          38.459727  3.150830
# 29              Nebraska         59.318072          38.857592  1.824336
# 30         Nebraska CD-1         55.486986          42.522034  1.990980
# 31         Nebraska CD-2         46.730541          51.323726  1.945733
# 32         Nebraska CD-3         76.033535          22.435869  1.530596
# 33                Nevada         50.591646          47.493131  1.915223
# 34         New Hampshire         47.873228          50.652804  1.473968
# 35            New Jersey         46.064631          51.974162  1.961207
# 36            New Mexico         45.851161          51.851900  2.296939
# 37              New York         39.421095          52.543148  8.035757
# 38        North Carolina         50.857191          47.645338  1.497471
# 39          North Dakota         66.956852          30.510790  2.532357
# 40                  Ohio         55.135799          43.928435  0.935766
# 41              Oklahoma         66.162103          31.899350  1.938547
# 42                Oregon         40.966044          55.273062  3.760894
# 43          Pennsylvania         50.372537          48.662806  0.964658
# 44           Puerto Rico         26.640910          73.359090  0.000000
# 45          Rhode Island         41.763118          55.544171  2.692711
# 46        South Carolina         58.228630          40.360891  1.410480
# 47          South Dakota         63.433678          34.239092  2.327230
# 48             Tennessee         64.193937          34.474053  1.332010
# 49                 Texas         56.139960          42.456655  1.403386
# 50                  Utah         59.376659          37.794308  2.829034
# 51               Vermont         32.319407          63.827005  3.853587
# 52              Virginia         46.057392          51.823867  2.118741
# 53            Washington         39.010967          57.228706  3.760327
# 54         West Virginia         69.966850          28.103002  1.930148
# 55             Wisconsin         49.595871          48.737042  1.667086
# 56               Wyoming         71.598005          25.841857  2.560138

# %%
# save as a parquet
output_path = "/content/drive/MyDrive/STA496/Datasets/pres24_results_data.parquet"
presresults24_df.to_parquet(output_path)
